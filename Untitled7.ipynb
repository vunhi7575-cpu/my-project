# %%
def tinh_giai_thua(n):
    if n == 0 or n == 1:
        return 1
    return n * tinh_giai_thua(n - 1)

n = 5
print(f"Giai thừa của {n} là: {tinh_giai_thua(n)}")
# Out:
# Giai thừa của 5 là: 120

# %%
n=5
gt=1
for i in range (1,n+1):
    gt=gt*i
print(gt)
# Out:
# 120

# %%
n=3
for cur_s in range (2*n):
   if(cur_s % 2 == 0):
    gt=1
    for i in range(1,cur_s+1):
      gt=gt*i
    print (gt)
# Out:
# 1
# 2
# 24
